# %% [markdown]
# - The outputs from the pest analysis is analyzed here. The following notebook provides a template for future notebooks. I have analyzed the outputs in two types:
#
# File name - ind_pargrp_mois_rw_itr.demo {This was the simulation in which we stopped the PEST run after 5 iterations}
#
# 1. Self-analysis (with inspiration from PEST-related articles, PESTools, PyEMU) - - Check from Pg. 100 - pestpp.5.0.8_manual.pdf
#     - Input data
#     - Sensitivity
#     - Objective function
#     - Residuals
#     - Relative contribution of temperature and moisture on the objective function
#     - Identifibility tool (TODO)
#     - Covariance matrix (TODO)
# 2. PESTools analysis (https://github.com/PESTools/pestools
#     - https://nbviewer.org/github/PESTools/pestools/blob/master/examples/MODFLOW%20and%20More%202015%20Paper.ipynb)

# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/rk/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import sys
sys.path.insert(0,'../pestools')

# %%
import os
main_cwd = os.getcwd()
print(main_cwd)
# Out:
# /home/rk/pestpp/pestpp/rk_model

# %%
from matplotlib.ticker import MaxNLocator
#import parsen

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.gridspec as gridspec

# %% [markdown]
# ### 1. Self-analysis (with inspiration from PEST-related articles, PESTools, PyEMU)
# #### a. Started with accessing the input data

# %%
directory_name = 'ind_pargrp_mois_rw_itr.demo'
cf_name = 'rk_model_glm_cf_v1_mois_rw' # Control file name

# %% [markdown]
# #### b. Parameter Sensitivity

# %%
sen_iteration = pd.read_csv(f'{directory_name}/{cf_name}.isen')
sen_iteration.index = sen_iteration['iteration']
sen_iteration.drop(axis=1, columns=['iteration'], inplace=True)
sen_iteration
# Out:
#                 n_m     tcs_m      af_m      af_p
# iteration
# 1          0.000030  0.000009  0.000021  0.000350
# 2          0.000040  0.000009  0.000046  0.000251
# 3          0.000049  0.000009  0.000104  0.000763
# 4          0.000057  0.000010  0.000068  0.000755
# 5          0.000065  0.000010  0.000072  0.000816
# 6          0.000065  0.000010  0.000080  0.000960

# %%
sen_iteration.iloc[0,:]
# Out:
# n_m      0.000030
# tcs_m    0.000009
# af_m     0.000021
# af_p     0.000350
# Name: 1, dtype: float64

# %%
# Example - Tried plotting using a for loop
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
#fig = plt.figure()
#fig.set_size_inches(10,5)
#ax = fig.add_axes([0,0,1,1])
#for
#X = np.arange(len(sen_iteration.index)) # Number of parts to consider
#x = len(sen_iteration.index)
#for i in X:
    #y = 0
    #ax.bar(X + (i+1)/x, sen_iteration.iloc[i,:], label=f'{i} itr', width=1/x)
    #y = (i+1)/x
#ax.bar(X + 0.25, sen_iteration.iloc[2,:], color='b', label='3rd itr', width=0.25)
#ax.bar(X + 0.5, sen_iteration.iloc[5,:], color='k', label='6th itr', width=0.25)

#ax.bar(X + 0.25, si_mineral_temp.iloc[0,:],color='tab:brown', label='mineral', width=0.25)
#ax.bar(X + 0.5, si_bedrock_temp.iloc[0,:], color='k', label='bedrock', width=0.25)
#major_ticks = np.arange(0, 4, 1)
#ax.set_xticks(major_ticks)
#labels = [item.get_text() for item in ax.get_xticklabels()]
#labels = ['n_m','tcs_m','alpha_m','alpha_p'] 
#ax.set_xticklabels(labels)
#ax.legend(fontsize=14)
#ax.set_ylabel('Sensitivity values', fontsize=15)
#ax.tick_params(axis='both', which='major', labelsize=10)
#ax.tick_params(axis='both', which='minor', labelsize=10)
#ax.set_xlabel('Parameters', fontsize=15)
#ax.grid()

# %%
# Example
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
fig = plt.figure()
fig.set_size_inches(10,5)
ax = fig.add_axes([0,0,1,1])
#for
X = np.arange(4) # Number of parts to consider
x = len(sen_iteration.index)

ax.bar(X + 0.0, sen_iteration.iloc[0,:], color='y', label='1st itr', width=0.2)
ax.bar(X + 0.25, sen_iteration.iloc[2,:], color='b', label='3rd itr', width=0.2)
ax.bar(X + 0.5, sen_iteration.iloc[4,:], color='k', label='5rd itr', width=0.2)
ax.bar(X + 0.75, sen_iteration.iloc[5,:], color='g', label='6th itr', width=0.2)

#ax.bar(X + 0.25, si_mineral_temp.iloc[0,:],color='tab:brown', label='mineral', width=0.25)
#ax.bar(X + 0.5, si_bedrock_temp.iloc[0,:], color='k', label='bedrock', width=0.25)
major_ticks = np.arange(0, 4, 1)
ax.set_xticks(major_ticks)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = ['n_m','tcs_m','alpha_m','alpha_p'] 
ax.set_xticklabels(labels)
ax.legend(fontsize=14)
ax.set_ylabel('Sensitivity values', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=10)
ax.set_xlabel('Parameters', fontsize=15)
ax.grid()

# %% [markdown]
# ##### Relative sensitivity values

# %%
sen_iteration.iloc[0,:].max()
# Out:
# 0.000350102

# %%
relative_set_itr = sen_iteration.copy()
for i, value in enumerate(sen_iteration.index):
    relative_set_itr.iloc[i,:] = relative_set_itr.iloc[0,:]/relative_set_itr.iloc[0,:].max()

relative_set_itr
# Out:
#                 n_m     tcs_m      af_m  af_p
# iteration
# 1          0.086295  0.026946  0.060693   1.0
# 2          0.086295  0.026946  0.060693   1.0
# 3          0.086295  0.026946  0.060693   1.0
# 4          0.086295  0.026946  0.060693   1.0
# 5          0.086295  0.026946  0.060693   1.0
# 6          0.086295  0.026946  0.060693   1.0

# %%
# Example
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
fig = plt.figure()
fig.set_size_inches(10,5)
ax = fig.add_axes([0,0,1,1])
#for
X = np.arange(4) # Number of parts to consider
x = len(sen_iteration.index)

ax.bar(X + 0.0, relative_set_itr.iloc[0,:], color='y', label='1st itr', width=0.2)
ax.bar(X + 0.25, relative_set_itr.iloc[2,:], color='b', label='3rd itr', width=0.2)
ax.bar(X + 0.5, relative_set_itr.iloc[4,:], color='k', label='5rd itr', width=0.2)
ax.bar(X + 0.75, relative_set_itr.iloc[5,:], color='g', label='6th itr', width=0.2)

#ax.bar(X + 0.25, si_mineral_temp.iloc[0,:],color='tab:brown', label='mineral', width=0.25)
#ax.bar(X + 0.5, si_bedrock_temp.iloc[0,:], color='k', label='bedrock', width=0.25)
major_ticks = np.arange(0, 4, 1)
ax.set_xticks(major_ticks)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = ['n_m','tcs_m','alpha_m','alpha_p'] 
ax.set_xticklabels(labels)
ax.legend(fontsize=14)
ax.set_ylabel('Sensitivity values', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=10)
ax.set_xlabel('Parameters', fontsize=15)
ax.grid()

# %% [markdown]
# ### Plotting the change in parameters:

# %%
par_iteration = pd.read_csv(f'{directory_name}/{cf_name}.ipar')
par_iteration.index = par_iteration['iteration']
par_iteration.drop(axis=1, columns=['iteration'], inplace=True)
par_iteration
# Out:
#                n_m    tcs_m      af_m      af_p
# iteration
# 0          1.20000  1.00000  0.050000  0.005000
# 1          1.16863  1.00265  0.033723  0.007969
# 2          1.15197  1.00379  0.020000  0.003731
# 3          1.13649  1.00279  0.020000  0.002000
# 4          1.12242  1.00383  0.020000  0.002000
# 5          1.12242  1.00383  0.020001  0.002007
# 6          1.12242  1.00383  0.020001  0.002016

# %% [markdown]
# ##### Changing the parameters relative to the initial value
# - To ensure that we can plot the changes with respect to the parameters, we subtract the parameter values w.r.t the initial values and then multiply by 100.
# \begin{equation}
#     par_{change} = \frac{(par_{final} - par_{initial})}{par_{initial}} * 100
# \end{equation}

# %%
par_change = par_iteration.copy()
#pargp_initial = par_change.iloc[0,:]
for i, index_value in enumerate(par_change.index):
    for j, col_value in enumerate(par_change.columns):
        #print(i, j)
        #print(par_change.iloc[i,j])
        par_change.iloc[i,j] = (par_iteration.iloc[i,j] - par_iteration.iloc[0,j])/par_iteration.iloc[0,j]*100
#np.abs(par_change)
par_change
# Out:
#                 n_m  tcs_m     af_m     af_p
# iteration
# 0          0.000000  0.000   0.0000   0.0000
# 1         -2.614167  0.265 -32.5542  59.3754
# 2         -4.002500  0.379 -60.0000 -25.3776
# 3         -5.292500  0.279 -60.0000 -60.0000
# 4         -6.465000  0.383 -60.0000 -60.0000
# 5         -6.465000  0.383 -59.9982 -59.8502
# 6         -6.465000  0.383 -59.9988 -59.6706

# %% [markdown]
# #### Line plot of all parameter values

# %%
fig = plt.figure()
fig.set_size_inches(10,5)
ax = fig.add_axes([0,0,1,1])

ax.plot(par_change.iloc[:,0], 'b', label='n_m')
ax.plot(par_change.iloc[:,1], 'k', label='tcs_m')
ax.plot(par_change.iloc[:,2], 'r', label='af_m')
ax.plot(par_change.iloc[:,3], 'g',label='af_p')

ax.set_title(f'Relative parameter value with each iteration: Initial values - n_m = {np.round(par_iteration.iloc[0,0],5)}, tcs_m = {np.round(par_iteration.iloc[0,1],5)}, af_m = {np.round(par_iteration.iloc[0,2],5)}, af_p = {np.round(par_iteration.iloc[0,3],5)}', fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=10)
ax.set_xlabel('Iteration number', fontsize=15)
ax.set_ylabel('Reltive parameter change (%)', fontsize=15)
ax.legend(fontsize=12)

ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid()

# %% [markdown]
# ### c. Objective function

# %%
no_iteration = np.arange(1,len(par_change.index),1)
no_iteration
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# Residual files - importing the values from the file
# Residual files after each iteration
no_iteration = np.arange(1,len(par_change.index),1)
for i, value in enumerate(no_iteration):
    locals()[f'res_{value}'] = pd.read_csv(f'{directory_name}/{cf_name}.rei{value}', skiprows=2,delim_whitespace=True)

#res_best = pd.read_csv(f'{directory_name}/rk_model_glm_cf.res', skiprows=2,delim_whitespace=True)
#res_best
res_4.head()
# Out:
#            Name Group  Measured    Modelled  Residual    Weight
# 0  stemp_0.04_0  temp  261.0233  270.150000 -9.126700  0.000719
# 1  stemp_0.04_1  temp  261.0067  260.598714  0.407986  0.000719
# 2  stemp_0.04_2  temp  260.8549  260.398036  0.456864  0.000719
# 3  stemp_0.04_3  temp  261.0327  261.067507 -0.034807  0.000719
# 4  stemp_0.04_4  temp  261.3470  261.189999  0.157001  0.000719

# %% [markdown]
# #### Analyzing the residual weights:

# %%
res_1['Weight'].describe()
# Out:
# count    5110.000000
# mean        0.000430
# std         0.000289
# min         0.000141
# 25%         0.000141
# 50%         0.000430
# 75%         0.000719
# max         0.000719
# Name: Weight, dtype: float64

# %%
res_1['Weight'].unique()
# Out:
# array([0.00071898, 0.00014113])

# %%
# Following the code from line 94 - file : res.py
def obj_fun(rei_df):
    """
    Function defined to calculate the objective function along with the residual values
    
    Input: rei_df - Residual dataframe
    
    
    """
    
    # Apply weighted residual and calculate phi contributions
    rei_df['Weighted_Residual'] = rei_df['Residual'] * rei_df['Weight']
    rei_df['Absolute_Residual'] = abs(rei_df['Residual'])
    rei_df['Weighted_Absolute_Residual'] = rei_df['Absolute_Residual'] * rei_df['Weight']
    
    # Calculate phi
    rei_df['Weighted_Sq_Residual'] = rei_df['Weighted_Residual']**2
    
    # Percentage contribution by each observation
    rei_df['Phi_Percent'] = rei_df['Weighted_Sq_Residual']/(rei_df['Weighted_Sq_Residual'].sum())*100
    
    return rei_df

# %%
# Finding the variation of residuals
for i, value in enumerate(no_iteration):
    locals()[f'res_phi_{value}'] = obj_fun(locals()[f'res_{value}'])
    
#res_phi_1 = obj_fun(res_1)
res_phi_1.head()
# Out:
#            Name Group  Measured    Modelled  Residual    Weight  \
# 0  stemp_0.04_0  temp  261.0233  270.150000 -9.126700  0.000719
# 1  stemp_0.04_1  temp  261.0067  260.698843  0.307857  0.000719
# 2  stemp_0.04_2  temp  260.8549  260.468276  0.386624  0.000719
# 3  stemp_0.04_3  temp  261.0327  261.114573 -0.081873  0.000719
# 4  stemp_0.04_4  temp  261.3470  261.230968  0.116032  0.000719
#
#    Weighted_Residual  Absolute_Residual  Weighted_Absolute_Residual  \
# 0          -0.006562           9.126700                    0.006562
# 1           0.000221           0.307857                    0.000221
# 2           0.000278           0.386624                    0.000278
# 3          -0.000059           0.081873                    0.000059
# 4           0.000083           0.116032                    0.000083
#
#    Weighted_Sq_Residual  Phi_Percent
# 0          4.305855e-05     0.782213
# 1          4.899260e-08     0.000890
# 2          7.726966e-08     0.001404
# 3          3.465112e-09     0.000063
# 4          6.959653e-09     0.000126

# %%
res_phi_1['Weighted_Sq_Residual'].mean()
# Out:
# 1.0772423461503694e-06

# %%
# Defining a dataframe with a objective function
# Changing the units by multiplying by 1e6

objfn_phi = pd.DataFrame(index=no_iteration,columns=['obj_func'])

for i, value in enumerate(no_iteration):
    objfn_phi.iloc[i,0] = locals()[f'res_phi_{i+1}']['Weighted_Sq_Residual'].mean()*1e7

objfn_phi.head()
# Out:
#     obj_func
# 1  10.772423
# 2   9.979779
# 3   9.564006
# 4   9.407458
# 5   9.398138

# %%
#fig, ax = plt.subplots(figsize=(14, 6))

#plt.figure(figsize=(10, 6))
#ax.plot(objfn_phi['obj_func'])
#ax.set_title('Plotting objective function with each iteration ', fontsize=15)
#ax.set_ylabel('Objective function (*1e7)', fontsize=12)
#ax.set_xlabel('Iteration number', fontsize=12)
#for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    #label.set_fontsize(10)
#plt.ylim(3.5, 3.6)
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))
#ax.grid()

# %% [markdown]
# The values were calculated using a formula. It not the same as the objective function calculated by the PEST program!

# %% [markdown]
# Comments:
#
# * It shows here that the second iteration has the least objective function value

# %% [markdown]
# How to determine the parameter dataset and residual values with the best dataset?

# %% [markdown]
# #### Accessing the objective function with every iteration

# %%
obj_iteration = pd.read_csv(f'{directory_name}/{cf_name}.iobj')
#obj_iteration.index = par_iteration['iteration']
obj_iteration.drop(axis=1, columns=['iteration'], inplace=True)
obj_iteration
# Out:
#    model_runs_completed  total_phi  measurement_phi  regularization_phi  \
# 0                     0   0.006000         0.006000                   0
# 1                    15   0.005505         0.005505                   0
# 2                    29   0.005100         0.005100                   0
# 3                    47   0.004887         0.004887                   0
# 4                    65   0.004807         0.004807                   0
# 5                    83   0.004802         0.004802                   0
# 6                   101   0.004801         0.004801                   0
#
#        temp      mois
# 0  0.003000  0.003000
# 1  0.002967  0.002538
# 2  0.002984  0.002116
# 3  0.002964  0.001923
# 4  0.002932  0.001875
# 5  0.002928  0.001875
# 6  0.002926  0.001875

# %%
fig, ax = plt.subplots(figsize=(14, 6))

plt.figure(figsize=(10, 6))
ax.plot(obj_iteration['total_phi']*1e3)
ax.set_title('Plotting objective function with each iteration', fontsize=15)
ax.set_ylabel('Objective function (*1e3)', fontsize=12)
ax.set_xlabel('Iteration number', fontsize=12)
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(10)
#plt.ylim(3.5, 3.6)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid()

# %% [markdown]
# **Comments:**
# - The objective function is reducing with each iteration.

# %% [markdown]
# ### d. Residuals
# 1. First choose the iteration with the minimum objective function value.
# 2. Then plot the residual based on this iteration

# %%
obj_iteration['total_phi'].idxmin()
# The iteration with the minimum objective function
# Out:
# 6

# %%
# Finding the index where we will be encountering the minimum objective function
itrno_best = obj_iteration['total_phi'].idxmin()

# Finding the corresponding residuals
res_best = locals()[f'res_{itrno_best}'].copy()

res_best.head()
# Out:
#            Name Group  Measured    Modelled  Residual    Weight  \
# 0  stemp_0.04_0  temp  261.0233  270.150000 -9.126700  0.000719
# 1  stemp_0.04_1  temp  261.0067  260.599478  0.407222  0.000719
# 2  stemp_0.04_2  temp  260.8549  260.398566  0.456334  0.000719
# 3  stemp_0.04_3  temp  261.0327  261.067863 -0.035163  0.000719
# 4  stemp_0.04_4  temp  261.3470  261.190304  0.156696  0.000719
#
#    Weighted_Residual  Absolute_Residual  Weighted_Absolute_Residual  \
# 0          -0.006562           9.126700                    0.006562
# 1           0.000293           0.407222                    0.000293
# 2           0.000328           0.456334                    0.000328
# 3          -0.000025           0.035163                    0.000025
# 4           0.000113           0.156696                    0.000113
#
#    Weighted_Sq_Residual  Phi_Percent
# 0          4.305855e-05     0.896816
# 1          8.572226e-08     0.001785
# 2          1.076461e-07     0.002242
# 3          6.391520e-10     0.000013
# 4          1.269258e-08     0.000264

# %%
temp_measured = res_best.iloc[:2555,2] # The 2nd column contains the measured values and we have only temperature values from the first 2555 values
mois_measured = res_best.iloc[2555:,2]

temp_sim = res_best.iloc[:2555,3] # The 3rd column contains the simulated values 
mois_sim = res_best.iloc[2555:,3]

temp_res = res_best.iloc[:2555,4] # The 4th column contains the residual values 
mois_res = res_best.iloc[2555:,4]

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
### Plotting the temperature for different alpha values at depth 0.01 m
fig2 = plt.figure(figsize=(20,15), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, height_ratios=[1,1,1,1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

fig2.suptitle(f'Plotting temperature at different depths [K] - Itr_no = {itrno_best}', fontsize=20)


depths = [0.04, 0.2, 0.4, 0.8, 1.2, 1.6]

time_period = np.arange(0,365)

x = 0

for j, depth in enumerate(depths):
    locals()['f2_ax'+str(j+1)].plot(time_period, temp_measured[x:x+365].values, 'k', label='measured')
    locals()['f2_ax'+str(j+1)].plot(time_period, temp_sim[x:x+365].values, 'r', label='simulated')
    locals()['f2_ax'+str(j+1)].set_title(f'{depth} m', fontsize=15)
    locals()['f2_ax'+str(j+1)].grid(True)
    #locals()['f2_ax'+str(j+1)].legend(fontsize=14)
    locals()['f2_ax'+str(j+1)].set_ylim(250,285)
    
    x = x + 365

    for label in (locals()['f2_ax'+str(j+1)].get_xticklabels() + locals()['f2_ax'+str(j+1)].get_yticklabels()):
        label.set_fontsize(13)
        
f2_ax3.legend(fontsize=14)  
f2_ax3.set_ylabel('Temperature (K)', fontsize=20)
f2_ax6.set_xlabel('Days', fontsize=20)
# Out:
# Text(0.5, 0, 'Days')

# %% [markdown]
# Comments:
# * Temperature estimates have improved on changing the top B.C as Temp. at 0.0 m

# %%
mois_measured.head()
# Out:
# 2555    8.001889
# 2556    8.008944
# 2557    8.001986
# 2558    8.016035
# 2559    8.037118
# Name: Measured, dtype: float64

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
### Plotting the temperature for different alpha values at depth 0.01 m
fig2 = plt.figure(figsize=(20,15), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, height_ratios=[1,1,1,1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

fig2.suptitle(f'Plotting soil moisture at different depths [K] - Itr_no = {itrno_best}', fontsize=20)


depths = [0.04, 0.2, 0.4, 0.8, 1.2, 1.6]

time_period = np.arange(0,365)

x = 0

for j, depth in enumerate(depths):
    locals()['f2_ax'+str(j+1)].plot(time_period, mois_measured[x:x+365].values, 'k', label='measured')
    locals()['f2_ax'+str(j+1)].plot(time_period, mois_sim[x:x+365].values, 'b', label='simulated')
    locals()['f2_ax'+str(j+1)].set_title(f'{depth} m', fontsize=15)
    locals()['f2_ax'+str(j+1)].grid(True)
    #locals()['f2_ax'+str(j+1)].legend(fontsize=14)
    locals()['f2_ax'+str(j+1)].set_ylim(0,100)
    
    x = x + 365

    for label in (locals()['f2_ax'+str(j+1)].get_xticklabels() + locals()['f2_ax'+str(j+1)].get_yticklabels()):
        label.set_fontsize(13)
        
f2_ax3.legend(fontsize=14)  
f2_ax3.set_ylabel('Volumetric water content (VWC)', fontsize=20)
f2_ax6.set_xlabel('Days', fontsize=20)
# Out:
# Text(0.5, 0, 'Days')

# %% [markdown]
# Comments:
# 1. The moisture estimates have remained more or less the same.! - The model process needs to be defined more accurately, change of parameters, addition of parameters, ..
# 2.

# %%
mois_measured[4519]
# Out:
# 37.60354

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Residual Histogram', fontsize=20)
fig.set_size_inches(18, 6)
ax1.hist(temp_res, bins=20, color='r')
ax2.hist(mois_res, bins=20, color='b')
ax1.set_ylabel('No. of observations')
ax1.set_title(f'Temp: Std.dev = {np.round(temp_res.std(),3)} K, Mean = {np.round(temp_res.mean(),3)} K')
ax2.set_title(f'Mois: Std.dev = {np.round(mois_res.std(),3)}, Mean = {np.round(mois_res.mean(),3)}')
ax1.set_xlabel('Temp (K)')
ax2.set_xlabel('Saturation of liquid')
plt.show()

# %% [markdown]
# **Comments:
#
# 1. The temperature observations show greater standard deviation compared to the moisture - Hence we need to consider to reweight the objective function.
# 2.  The temperature is more or less equally distributed along the center.
# 3. The moisture depicts a skew along the positive side of saturation of liquid.

# %%
temp_res.describe()
# Out:
# count    2555.000000
# mean        0.951839
# std         1.144584
# min        -9.126700
# 25%         0.294511
# 50%         0.938164
# 75%         1.516885
# max         5.649265
# Name: Residual, dtype: float64

# %%
plt.figure(figsize=(6, 6))
plt.hexbin(temp_measured, temp_sim, gridsize=(20,20), cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.hexbin(mois_measured, mois_sim, gridsize=(20,20), cmap=plt.cm.Blues)
plt.colorbar()
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Hexagonal Bin plot of simulated Vs Measured', fontsize=20)
fig.set_size_inches(18, 6)
ax1.hexbin(temp_measured, temp_sim, gridsize=(20,20), cmap=plt.cm.Reds)
#plt.colorbar()
ax1.set_ylabel('Simulated')
ax1.set_xlabel('Measured')
ax1.set_title('Temperature')

ax2.hexbin(mois_measured, mois_sim, gridsize=(20,20), cmap=plt.cm.Blues)
ax2.set_ylabel('Simulated')
ax2.set_xlabel('Measured')
ax2.set_title('Moisture')

#plt.colorbar(cax=ax1)

#ax1.hist(temp_res, bins=20, color='r')
#ax2.hist(mois_res, bins=20, color='b')
#ax1.set_ylabel('No. of observations')
#ax1.set_title(f'Temp: Std.dev = {np.round(temp_res.std(),3)} K, Mean = {np.round(temp_res.mean(),3)} K')
#ax2.set_title(f'Mois: Std.dev = {np.round(mois_res.std(),3)}, Mean = {np.round(mois_res.mean(),3)}')
#ax1.set_xlabel('Temp (K)')
#ax2.set_xlabel('Saturation of liquid')
#img1 = ax1.imshow(fig)
#fig.colorbar(img1)
# Out:
# Text(0.5, 1.0, 'Moisture')

# %% [markdown]
# #### f. Relative contribution of temperature and moisture on the objective function

# %%
obj_iteration
# Out:
#     model_runs_completed  total_phi  measurement_phi  regularization_phi  \
# 0                      0   0.000264         0.000264                   0
# 1                     15   0.000262         0.000262                   0
# 2                     29   0.000261         0.000261                   0
# 3                     47   0.000256         0.000256                   0
# 4                     65   0.000250         0.000250                   0
# 5                     83   0.000246         0.000246                   0
# 6                    101   0.000240         0.000240                   0
# 7                    119   0.000238         0.000238                   0
# 8                    137   0.000237         0.000237                   0
# 9                    155   0.000235         0.000235                   0
# 10                   173   0.000233         0.000233                   0
# 11                   191   0.000232         0.000232                   0
# 12                   209   0.000230         0.000230                   0
# 13                   227   0.000228         0.000228                   0
# 14                   245   0.000228         0.000228                   0
# 15                   263   0.000226         0.000226                   0
# 16                   281   0.000224         0.000224                   0
# 17                   299   0.000223         0.000223                   0
# 18                   317   0.000222         0.000222                   0
#
#         temp      mois
# 0   0.000132  0.000132
# 1   0.000131  0.000132
# 2   0.000132  0.000129
# 3   0.000131  0.000124
# 4   0.000131  0.000118
# 5   0.000131  0.000114
# 6   0.000132  0.000107
# 7   0.000132  0.000106
# 8   0.000132  0.000105
# 9   0.000133  0.000103
# 10  0.000132  0.000101
# 11  0.000132  0.000100
# 12  0.000132  0.000098
# 13  0.000132  0.000097
# 14  0.000132  0.000096
# 15  0.000131  0.000095
# 16  0.000130  0.000094
# 17  0.000131  0.000093
# 18  0.000131  0.000092

# %%
# Storing the iteration with the least objective function
obj_itr_best = obj_iteration.iloc[itrno_best,:]

np.array(obj_itr_best[['temp','mois']])*1e6
# Out:
# array([130.677 ,  91.5401])

# %%
# Storing the iteration with the least objective function
obj_itr_best = obj_iteration.iloc[itrno_best,:]

con_variables = np.array(obj_itr_best[['temp','mois']])/obj_itr_best['measurement_phi']*100

### To find the percentage contribution, we need subtract it with total_phi and multiply 

plt.figure(figsize=(6,6))
plt.title('Relative contribution of temperature and moisture')
mylabels=[f'Temp - {np.round(con_variables[0],3)} %',f'Mois - {np.round(con_variables[1],3)} %']
plt.pie(con_variables,labels=mylabels)
#plt.legend()
plt.show()
#plt.legend()

# %% [markdown]
# #### f. Identifibility tool - Identifiability is defined here as the capability of model calibration to constrain parameters used by a model.
# - Go through the article and extract results later!
#
# #### g. Plotting the covariance matrix for the variables

# %% [markdown]
# ### Reweighting strategy:

# %%
res_1['new_w'] = res_1
# Out:
#                Name Group    Measured    Modelled  Residual    Weight  \
# 0      stemp_0.04_0  temp  261.023264  270.150000 -9.126736  0.000196
# 1      stemp_0.04_1  temp  261.006667  260.607825  0.398842  0.000196
# 2      stemp_0.04_2  temp  260.854861  260.405492  0.449369  0.000196
# 3      stemp_0.04_3  temp  261.032708  261.071966 -0.039258  0.000196
# 4      stemp_0.04_4  temp  261.347014  261.194927  0.152087  0.000196
# ...             ...   ...         ...         ...       ...       ...
# 5105  smois_1.6_360  mois    0.168612    0.113117  0.055494  0.000196
# 5106  smois_1.6_361  mois    0.167619    0.112864  0.054755  0.000196
# 5107  smois_1.6_362  mois    0.166811    0.112611  0.054200  0.000196
# 5108  smois_1.6_363  mois    0.166060    0.112329  0.053732  0.000196
# 5109  smois_1.6_364  mois    0.165318    0.112018  0.053300  0.000196
#
#       Weighted_Residual  Absolute_Residual  Weighted_Absolute_Residual  \
# 0             -0.001786           9.126736                    0.001786
# 1              0.000078           0.398842                    0.000078
# 2              0.000088           0.449369                    0.000088
# 3             -0.000008           0.039258                    0.000008
# 4              0.000030           0.152087                    0.000030
# ...                 ...                ...                         ...
# 5105           0.000011           0.055494                    0.000011
# 5106           0.000011           0.054755                    0.000011
# 5107           0.000011           0.054200                    0.000011
# 5108           0.000011           0.053732                    0.000011
# 5109           0.000010           0.053300                    0.000010
#
#       Weighted_Sq_Residual  Phi_Percent
# 0             3.189989e-06     1.412808
# 1             6.092002e-09     0.002698
# 2             7.733295e-09     0.003425
# 3             5.902111e-11     0.000026
# 4             8.858081e-10     0.000392
# ...                    ...          ...
# 5105          1.179374e-10     0.000052
# 5106          1.148186e-10     0.000051
# 5107          1.125003e-10     0.000050
# 5108          1.105648e-10     0.000049
# 5109          1.087979e-10     0.000048
#
# [5110 rows x 11 columns]

# %% [markdown]
# ### PESTools
# - Check it out later - Correct the python code

# %%
# Direct it to the demo folder
example = pestools.Pest('test_pest_iterations_2.demo/{cf_name}')
directory_name = 'test_pest_iterations_2.demo'

# %%
example.parameter_data
# The above line might have not worked since we have a different PEST control file - version 2 (Do we consdider changing the version?)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-3a5ccb414f84> in <module>
# ----> 1 example.parameter_data
#       2 # The above line might have not worked since we have a different PEST control file - version 2 (Do we consdider changing the version?)
#
# ~/pestpp/pestpp/pestools/pestools/pest.py in parameter_data(self)
#     160         DataFrame of parameter data in .pst file
#     161         '''
# --> 162         parameter_data = self.pst.parameter_data
#     163         return parameter_data
#     164
#
# ~/pestpp/pestpp/pestools/pestools/pest.py in pst(self)
#      88         Pst Class
#      89         '''
# ---> 90         pst = Pst(self.pstfile)
#      91         return pst
#      92
#
# ~/pestpp/pestpp/pestools/pestools/pst_handler.py in __init__(self, filename, load, resfile)
#      54         if load:
#      55             assert os.path.exists(filename)
# ---> 56             self.load(filename)
#      57
#      58
#
# ~/pestpp/pestpp/pestools/pestools/pst_handler.py in load(self, filename)
#     239             self.estimation = False
#     240         raw = f.readline().strip().split()
# --> 241         npar, nobs, nprior = int(raw[0]), int(raw[1]), int(raw[3])
#     242         f.close()
#     243         f = open(filename, 'r')
#
# ValueError: invalid literal for int() with base 10: 'noptmax'

# %%
example.observation_data
# Out:
#                       obsnme      obsval    weight obgnme
# obsnme
# stemp_0.04_0    stemp_0.04_0  261.023264  0.000196   temp
# stemp_0.04_1    stemp_0.04_1  261.006667  0.000196   temp
# stemp_0.04_2    stemp_0.04_2  260.854861  0.000196   temp
# stemp_0.04_3    stemp_0.04_3  261.032708  0.000196   temp
# stemp_0.04_4    stemp_0.04_4  261.347014  0.000196   temp
# ...                      ...         ...       ...    ...
# smois_1.6_360  smois_1.6_360    0.168612  0.000196   mois
# smois_1.6_361  smois_1.6_361    0.167619  0.000196   mois
# smois_1.6_362  smois_1.6_362    0.166811  0.000196   mois
# smois_1.6_363  smois_1.6_363    0.166060  0.000196   mois
# smois_1.6_364  smois_1.6_364    0.165318  0.000196   mois
#
# [5110 rows x 4 columns]

# %%
# Using a normal method to access the parameter data:
# Exporting the parameter group csv file
pargrp = pd.read_csv(f'{directory_name}/rk_model_glm.pargrp_data.csv')
pargrp
# Out:
#     pargpnme    inctyp  derinc  derinclb  forcen  derincmul    dermthd
# 0    thermal  relative    0.01       0.0  switch        1.0  parabolic
# 1  hydraulic  relative    0.01       0.0  switch        1.0  parabolic

# %% [markdown]
# ### Residuals
# Following a PEST run, residual information can be read in, from a single .res file, or set of .rei files containing residual information by iteration. Ancillary observation information such as spatial coordinates, date/time, or measurement type can be read in from an observation information file.

# %% [markdown]
# #### Following notebook - https://nbviewer.org/github/pestools/pestools/blob/master/examples/Res.ipynb

# %%
# Extracting the 3rd residual file
res_3 = pestools.Res(f'{directory_name}/{cf_name}.rei3')
#residuals.plot_hexbin(['head_fair','wcrs1'],print_stats=['Mean','MAE','RMSE'])

# %%
res_3.df.head()
# Out:
#                       Name Group    Measured    Modelled  Residual    Weight  \
# stemp_0.04_0  stemp_0.04_0  temp  261.023264  270.150000 -9.126736  0.000196
# stemp_0.04_1  stemp_0.04_1  temp  261.006667  261.661200 -0.654534  0.000196
# stemp_0.04_2  stemp_0.04_2  temp  260.854861  261.466022 -0.611161  0.000196
# stemp_0.04_3  stemp_0.04_3  temp  261.032708  262.668817 -1.636109  0.000196
# stemp_0.04_4  stemp_0.04_4  temp  261.347014  263.258102 -1.911088  0.000196
#
#               Weighted_Residual  Absolute_Residual  \
# stemp_0.04_0          -0.001786           9.126736
# stemp_0.04_1          -0.000128           0.654534
# stemp_0.04_2          -0.000120           0.611161
# stemp_0.04_3          -0.000320           1.636109
# stemp_0.04_4          -0.000374           1.911088
#
#               Weighted_Absolute_Residual  Weighted_Sq_Residual
# stemp_0.04_0                    0.001786          3.189989e-06
# stemp_0.04_1                    0.000128          1.640673e-08
# stemp_0.04_2                    0.000120          1.430439e-08
# stemp_0.04_3                    0.000320          1.025138e-07
# stemp_0.04_4                    0.000374          1.398684e-07

# %%
res_3.phi.head()
# Out:
#               Weighted_Sq_Residual
# stemp_0.04_0          3.189989e-06
# stemp_0.04_1          1.640673e-08
# stemp_0.04_2          1.430439e-08
# stemp_0.04_3          1.025138e-07
# stemp_0.04_4          1.398684e-07

# %%
res_3.phi_by_group.head()
# Out:
#        Weighted_Sq_Residual    Percent
# Group
# mois               0.000005   0.801748
# temp               0.000641  99.198252

# %% [markdown]
# * Comments: We need to definitely rescale the weights by using the function PWTADJ1

# %%
obsgroups = [g for g in res_3.obs_groups if 'regul' not in g]
obsgroups
# Out:
# ['mois', 'temp']

# %%
res_3.describe_groups(['temp'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-fd7661c8a51a> in <module>
# ----> 1 res_3.describe_groups(['temp'])
#
# ~/anaconda3/lib/python3.8/site-packages/pestools/res.py in describe_groups(self, groups, exclude_zero, ddof)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
res_3.describe_groups('temp').loc[['Mean', 'MAE', 'RMSE']]

# %%
res_3.describe_groups('mois').loc[['Mean', 'MAE', 'RMSE']]
# Out:
#      Group summary
# Mean      0.160113
# MAE       0.163279
# RMSE      0.230156

# %%
res_3.description
# Out:
#            n     Range       Max       Min      Mean Standard deviation  \
# mois  2555.0  1.577963  1.137808 -0.440155  0.160113           0.165367
# temp  2555.0  17.09038  7.963644 -9.126736   1.66466           1.945372
#
#       Varience       25%       50%       75% Max (absolute) Min (absolute)  \
# mois  0.027346  0.057943  0.087693  0.212841       1.137808       0.000035
# temp  3.784472  0.610736  1.657419  2.875546       9.126736       0.000241
#
#            MAE      RMSE RMSE/range Normally Distributed p-value
# mois  0.163279  0.230156   0.145857                 True     0.0
# temp  2.087973  2.560094   0.149797                 True     0.0

# %%
res_3.df.iloc[2555:,:]
# Out:
#                         Name Group  Measured  Modelled  Residual    Weight  \
# smois_0.04_0    smois_0.04_0  mois  0.160038  0.112516  0.047522  0.000196
# smois_0.04_1    smois_0.04_1  mois  0.160179  0.107321  0.052858  0.000196
# smois_0.04_2    smois_0.04_2  mois  0.160040  0.107272  0.052768  0.000196
# smois_0.04_3    smois_0.04_3  mois  0.160321  0.107593  0.052727  0.000196
# smois_0.04_4    smois_0.04_4  mois  0.160742  0.107771  0.052972  0.000196
# ...                      ...   ...       ...       ...       ...       ...
# smois_1.6_360  smois_1.6_360  mois  0.168612  0.110668  0.057944  0.000196
# smois_1.6_361  smois_1.6_361  mois  0.167619  0.110599  0.057020  0.000196
# smois_1.6_362  smois_1.6_362  mois  0.166811  0.110518  0.056293  0.000196
# smois_1.6_363  smois_1.6_363  mois  0.166060  0.110392  0.055669  0.000196
# smois_1.6_364  smois_1.6_364  mois  0.165318  0.110221  0.055097  0.000196
#
#                Weighted_Residual  Absolute_Residual  \
# smois_0.04_0            0.000009           0.047522
# smois_0.04_1            0.000010           0.052858
# smois_0.04_2            0.000010           0.052768
# smois_0.04_3            0.000010           0.052727
# smois_0.04_4            0.000010           0.052972
# ...                          ...                ...
# smois_1.6_360           0.000011           0.057944
# smois_1.6_361           0.000011           0.057020
# smois_1.6_362           0.000011           0.056293
# smois_1.6_363           0.000011           0.055669
# smois_1.6_364           0.000011           0.055097
#
#                Weighted_Absolute_Residual  Weighted_Sq_Residual
# smois_0.04_0                     0.000009          8.648455e-11
# smois_0.04_1                     0.000010          1.070003e-10
# smois_0.04_2                     0.000010          1.066354e-10
# smois_0.04_3                     0.000010          1.064709e-10
# smois_0.04_4                     0.000010          1.074603e-10
# ...                                   ...                   ...
# smois_1.6_360                    0.000011          1.285786e-10
# smois_1.6_361                    0.000011          1.245133e-10
# smois_1.6_362                    0.000011          1.213565e-10
# smois_1.6_363                    0.000011          1.186804e-10
# smois_1.6_364                    0.000011          1.162572e-10
#
# [2555 rows x 10 columns]

# %%
temp_measured = res_3.df.iloc[:2555,2] # The 2nd column contains the measured values and we have only temperature values from the first 2555 values
mois_measured = res_3.df.iloc[2555:,2]

temp_sim = res_3.df.iloc[:2555,3] # The 3rd column contains the simulated values 
mois_sim = res_3.df.iloc[2555:,3]

temp_res = res_3.df.iloc[:2555,4] # The 4th column contains the residual values 
mois_res = res_3.df.iloc[2555:,4]

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Residual Histogram', fontsize=20)
fig.set_size_inches(18, 6)
ax1.hist(temp_res, bins=20, color='r')
ax2.hist(mois_res, bins=20, color='b')
ax1.set_ylabel('No. of observations')
ax1.set_title(f'Temp: Std.dev = {np.round(temp_res.std(),3)} K, Mean = {np.round(temp_res.mean(),3)} K')
ax2.set_title(f'Mois: Std.dev = {np.round(mois_res.std(),3)}, Mean = {np.round(mois_res.mean(),3)}')
ax1.set_xlabel('Temp (K)')
ax2.set_xlabel('Saturation of liquid')
plt.show()

# %% [markdown]
# **Comments:
#
# 1. The temperature observations show greater standard deviation compared to the moisture - Hence we need to consider to reweight the objective function.
# 2.  The temperature is more or less equally distributed along the center.
# 3. The moisture depicts a skew along the positive side of saturation of liquid.

# %%
temp_res.describe()
# Out:
# count    2555.000000
# mean        1.664660
# std         1.945372
# min        -9.126736
# 25%         0.610736
# 50%         1.657419
# 75%         2.875546
# max         7.963644
# Name: Residual, dtype: float64

# %%
parsen = example.ParSen(drop_regul=True)
# Note: in the official manuscript the above line was: example.ParSen(r'../cc/Columbia', drop_regul=True)
# that was incorrect, the base name is already known and part of the Pest class (example)
parsen.plot(n=20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-162-9f60e69ccf40> in <module>
# ----> 1 parsen = example.ParSen(drop_regul=True)
#       2 # Note: in the official manuscript the above line was: example.ParSen(r'../cc/Columbia', drop_regul=True)
#       3 # that was incorrect, the base name is already known and part of the Pest class (example)
#       4 parsen.plot(n=20)
#
# ~/.local/lib/python3.8/site-packages/pestools/pest.py in ParSen(self, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/pestools/pest.py in jco_df(self)
#
# ~/.local/lib/python3.8/site-packages/pestools/pest.py in _jco(self)
#
# ~/.local/lib/python3.8/site-packages/pestools/mat_handler.py in from_binary(self, filename)
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %% [markdown]
# #### Deal with it later - You may need to download PESTools once more & setup the directory structure properly

# %%
res_3.plot_hexbin(['temp', 'mois'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-163-bad1cb48e709> in <module>
# ----> 1 res_3.plot_hexbin(['temp', 'mois'])
#
# ~/.local/lib/python3.8/site-packages/pestools/res.py in plot_hexbin(self, groupinfo, title, print_stats, print_format, exclude_zero_stats, line_kwds, **kwds)
#
# ~/.local/lib/python3.8/site-packages/pestools/plots.py in __init__(self, df, x, y, groupinfo, error_bars_obs, line_kwds, **kwds)
#
# ~/.local/lib/python3.8/site-packages/pestools/plots.py in __init__(self, df, x, y, groupinfo, group_col, line_kwds, legend_kwds, **kwds)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plt.figure(figsize=(6, 6))
plt.hexbin(temp_measured, temp_sim, gridsize=(20,20), cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Hexagonal Bin plot of simulated Vs Measured', fontsize=20)
fig.set_size_inches(18, 6)
ax1.hexbin(temp_measured, temp_sim, gridsize=(20,20), cmap=plt.cm.Reds)
#plt.colorbar()
ax1.set_ylabel('Simulated')
ax1.set_xlabel('Measured')
ax1.set_title('Temperature')

ax2.hexbin(mois_measured, mois_sim, gridsize=(20,20), cmap=plt.cm.Blues)
ax2.set_ylabel('Simulated')
ax2.set_xlabel('Measured')
ax2.set_title('Moisture')

#plt.colorbar(cax=ax1)

#ax1.hist(temp_res, bins=20, color='r')
#ax2.hist(mois_res, bins=20, color='b')
#ax1.set_ylabel('No. of observations')
#ax1.set_title(f'Temp: Std.dev = {np.round(temp_res.std(),3)} K, Mean = {np.round(temp_res.mean(),3)} K')
#ax2.set_title(f'Mois: Std.dev = {np.round(mois_res.std(),3)}, Mean = {np.round(mois_res.mean(),3)}')
#ax1.set_xlabel('Temp (K)')
#ax2.set_xlabel('Saturation of liquid')
#img1 = ax1.imshow(fig)
#fig.colorbar(img1)
# Out:
# Text(0.5, 1.0, 'Moisture')

# %%
len(np.arange(0,364))
# Out:
# 364

# %%
len(temp_measured[0:364])
# Out:
# 364

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
### Plotting the temperature for different alpha values at depth 0.01 m
fig2 = plt.figure(figsize=(20,15), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, height_ratios=[1,1,1,1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

plt.title('Plotting soil temperature at different depths [K]')


depths = [0.04, 0.2, 0.4, 0.8, 1.2, 1.6]

time_period = np.arange(0,365)

x = 0

for j, depth in enumerate(depths):
    locals()['f2_ax'+str(j+1)].plot(time_period, temp_measured[x:x+365].values, 'k', label='measured')
    locals()['f2_ax'+str(j+1)].plot(time_period, temp_sim[x:x+365].values, 'r', label='simulated')
    locals()['f2_ax'+str(j+1)].set_title(f'{depth} m')
    locals()['f2_ax'+str(j+1)].grid(True)
    locals()['f2_ax'+str(j+1)].legend()
    locals()['f2_ax'+str(j+1)].set_ylim(250,285)
    
    x = x + 365
    
f2_ax3.set_ylabel('Temperature (K)', fontsize=20)
# Out:
# Text(0, 0.5, 'Temperature (K)')

# %% [markdown]
# Comments:
# * Include the parameters at the top.
# * Include the initial measurements without the calibration.
# * Include information about the residuals
# * Add a heading!
# *

# %%
mois_measured
# Out:
# smois_0.04_0     0.160038
# smois_0.04_1     0.160179
# smois_0.04_2     0.160040
# smois_0.04_3     0.160321
# smois_0.04_4     0.160742
#                    ...
# smois_1.6_360    0.168612
# smois_1.6_361    0.167619
# smois_1.6_362    0.166811
# smois_1.6_363    0.166060
# smois_1.6_364    0.165318
# Name: Measured, Length: 2555, dtype: float64

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
### Plotting the temperature for different alpha values at depth 0.01 m
fig2 = plt.figure(figsize=(20,15), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, height_ratios=[1,1,1,1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

plt.title('Plotting soil moisture at different depths [K]')


depths = [0.04, 0.2, 0.4, 0.8, 1.2, 1.6]

time_period = np.arange(0,365)

x = 0

for j, depth in enumerate(depths):
    locals()['f2_ax'+str(j+1)].plot(time_period, mois_measured[x:x+365].values, 'k', label='measured')
    locals()['f2_ax'+str(j+1)].plot(time_period, mois_sim[x:x+365].values, 'b', label='simulated')
    locals()['f2_ax'+str(j+1)].set_title(f'{depth} m')
    locals()['f2_ax'+str(j+1)].grid(True)
    locals()['f2_ax'+str(j+1)].legend()
    locals()['f2_ax'+str(j+1)].set_ylim(0,1)
    
    x = x + 365
    
f2_ax3.set_ylabel('Saturation of liquid', fontsize=20)
# Out:
# Text(0, 0.5, 'Saturation of liquid')

# %% [markdown]
# Comments:
#
# 1. We need to change the boundary condition at the top! - Temperature at 0.00 cm
# 2. Since it is given lesser importance - I think that is why it has not been calibrated properly!

# %% [markdown]
# ### Parameter sensitivity:

# %%
import parsen
import mat_handler

# %%
parsen_plots = parsen.ParSen(f'test_pest_iterations_2.demo/{cf_name}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-175-9aa8ea11c30e> in <module>
# ----> 1 parsen_plots = parsen.ParSen('test_pest_iterations_2.demo/rk_model_glm_cf')
#
# ~/pestpp/pestpp/pestools/parsen.py in __init__(self, basename, parameter_data, res_df, jco_df, drop_regul, drop_groups, keep_groups, keep_obs, remove_obs)
#     109                 self.directory = os.getcwd()
#     110
# --> 111
#     112         if jco_df is None:
#     113             jco_file = os.path.join(self.directory, self.basename + '.jco')
#
# ~/.local/lib/python3.8/site-packages/pestools/mat_handler.py in from_binary(self, filename)
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
#fig, ax = res_3.plot_one2one('temp', print_stats=['Mean', 'MAE','RMSE'])
